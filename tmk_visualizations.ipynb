# %%
import pandas as pd
import plotly.express as px

wh_df = pd.read_csv('data/world-happiness-report.csv')
wh_df21 = pd.read_csv('data/world-happiness-report-2021.csv')
# df.to_csv('data/world-happiness-report-2021.csv')

# %%
# df.to_csv('data/world-happiness-report-2021.csv')

# %%
wh_df21 = pd.read_csv('data/world-happiness-report-2021.csv')

# %%
wh_df21[wh_df21.columns[wh_df21.columns != 'Ladder score in Dystopia']]
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
wh_df21
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
wh_df.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
wh_df[wh_df['Country name'] == 'Afghanistan']
# Out:
#    Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0   Afghanistan  2008        3.724               7.370           0.451
# 1   Afghanistan  2009        4.402               7.540           0.552
# 2   Afghanistan  2010        4.758               7.647           0.539
# 3   Afghanistan  2011        3.832               7.620           0.521
# 4   Afghanistan  2012        3.783               7.705           0.521
# 5   Afghanistan  2013        3.572               7.725           0.484
# 6   Afghanistan  2014        3.131               7.718           0.526
# 7   Afghanistan  2015        3.983               7.702           0.529
# 8   Afghanistan  2016        4.220               7.697           0.559
# 9   Afghanistan  2017        2.662               7.697           0.491
# 10  Afghanistan  2018        2.694               7.692           0.508
# 11  Afghanistan  2019        2.375               7.697           0.420
#
# ...

# %%
wh_df21
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
wh_df21.describe() #A little more description of the data
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %%
wh_df21.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
#Questions formulated to recieve data
#Social Support=  “If you were in trouble, do you have relatives or friends you can count on to help you whenever you need them, or not?” (0=no, 1=yes)
#Freedom= "Are you satisfied or dissatisfied with your freedom to choose what you do with your life?”(0=no 1=yes)
#Generosity= “Have you donated money to a charity in the past month?”
#Corruption= "Is corruption widespread throughout the government in this country or not?” this is also applied with gov information

# %%
# meaning of column names

# Country name - Essential
# Regional Indicator is the region of the country and could be used when looking at data on a wider scale
# Ladder Score: rate their own current lives on a scalre of 0 to 10 (0 = worst, 10 = best)
# Standerd Error of Ladder Score: the statistical accuracy of the measurement - not essential
# Upper/Lower Whisker: the values between Q3 and max (Upper) and the values between min and Q1 (lower) - not essential
# Logged GDP capita - Essential
# Social Support: Assitance provided by the community to an individual - Red Flag (what's it measured in).
# Healthy Life Expectancy: Average number of years that a person can expect to live in full health - Essential
# Freedom to make Life Choices - Red Flag (very vague)
# Generosity: the average response to the question "Have you donated money to charity in the past month" - not essential or relevant
# Perceptions of Corruption: The measure is the national average of the survey responses to two questions in the GWP: “Is corruption widespread throughout the government or not” and “Is corruption widespread within businesses or not?” - Red Flag (could recieve biased responses)
# Ladder Score in Dystopia - The precentage of happiness in a country compare to the "world saddest country"(a dystopia where all the column values are low) not essential
# Explained By Columns - not essential

# %%
# dropping columns

columns_to_drop = ['Standard error of ladder score', 'upperwhisker', 'lowerwhisker', 'Explained by: Log GDP per capita', 'Explained by: Social support',
       'Explained by: Healthy life expectancy',
       'Explained by: Freedom to make life choices',
       'Explained by: Generosity', 'Explained by: Perceptions of corruption']
wh_df21.drop(columns_to_drop, axis=1, inplace = True)

# %%
Social_support= wh_df21['Social support']

# %%
Social_support.max()
# Out:
# 0.983

# %%
Social_support.min()
# Out:
# 0.463

# %%
wh_df21.shape #number of rows and columns in dataset
# Out:
# (149, 11)

# %%
wh_df21.dropna(inplace=True)
wh_df21.reset_index(drop=True, inplace=True) #to drop na values

# %%
wh_df21['Regional indicator'].value_counts() #number of countries within regions
# Out:
# Sub-Saharan Africa                    36
# Western Europe                        21
# Latin America and Caribbean           20
# Middle East and North Africa          17
# Central and Eastern Europe            17
# Commonwealth of Independent States    12
# Southeast Asia                         9
# South Asia                             7
# East Asia                              6
# North America and ANZ                  4
# Name: Regional indicator, dtype: int64

# %%
wh_df21
# Out:
#     Country name  Regional indicator  Ladder score  Logged GDP per capita  \
# 0        Finland      Western Europe         7.842                 10.775
# 1        Denmark      Western Europe         7.620                 10.933
# 2    Switzerland      Western Europe         7.571                 11.117
# 3        Iceland      Western Europe         7.554                 10.878
# 4    Netherlands      Western Europe         7.464                 10.932
# ..           ...                 ...           ...                    ...
# 144      Lesotho  Sub-Saharan Africa         3.512                  7.926
# 145     Botswana  Sub-Saharan Africa         3.467                  9.782
# 146       Rwanda  Sub-Saharan Africa         3.415                  7.676
# 147     Zimbabwe  Sub-Saharan Africa         3.145                  7.943
# 148  Afghanistan          South Asia         2.523                  7.695
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
wh_df.columns #to compare with 2021 columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
import plotly.express as px #importing plotly for any future usage

# %%
#scatter plot: Freedom to make life choices vs. Perceptions of corruption
fig = px.scatter(wh_df21, x="Freedom to make life choices", y="Perceptions of corruption", color="Country name", title="Freedom vs Corruption by Location & Dystopia", size="Dystopia + residual")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# scatter plot: Healthy Life Expectancy vs. Ladder Score

fig_hle_vs_ls = px.scatter(wh_df21, x = 'Healthy life expectancy', y = 'Ladder score', color = 'Country name', title = 'Healthy Life Expectancy vs. Ladder Score')
fig_hle_vs_ls.show()

# conclusion: shows positive, medium/strong correlation
# in general, the higher the healthy life expectancy, the higher the ladder score & the happier the general country is.
# a couple of outliers (high healthy life expectancy but relatively lower ladder score)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#scatter plot gdp vs. generosity
import plotly.express as px
fig = px.scatter(wh_df21, x="Logged GDP per capita", y="Generosity", size="Healthy life expectancy", color="Country name", trendline='ols')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# There is no clear trend demonstrated between the generosity and logged GDP per capita of countries.

# %%
#scatter plot gdp vs. life expectancy
import plotly.express as px
fig = px.scatter(wh_df21, x="Logged GDP per capita", y="Healthy life expectancy", size="Social support", color="Regional indicator")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Sub\-Saharan African countries tend to have a lower healthy life expectancy and logged GDP per capita.
#
# Western European countries predominantly have the highest healthy life expectancy and logged GDP per capita.
#
# There is a positive correlation between healthy life expectancy and logged GDP per capita of regions.

# %%
#scatter matrix
numerical_wh_df21 = wh_df21[['Logged GDP per capita', 'Healthy life expectancy', 'Ladder score']]
fig = px.scatter_matrix(numerical_wh_df21, color='Healthy life expectancy')
fig.show()
# Out:
# /projects/edd1874b-535e-4ea0-8897-aa8a85e79c89/miniconda3/lib/python3.10/site-packages/plotly/express/_core.py:279: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# There is a positive trend for all the graphs, indicating that healthy life expectancy, ladder score, and logged GDP per capita depend on one another.

# %%
#scatter plot average gdp vs. average life expectancy
import plotly.express as px
fig = px.scatter(gb_wh21, x="Logged GDP per capita", y="Perceptions of corruption", size="Social support", color="Regional indicator", title= "GDP vs. Average Life Expectancy")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The negative trend between perceptions of corruption and logged GDP per capita indicates that regions with higher perceptions of corruption are less likely to have a higher GDP per capita.

# %%
#scatter plot social support vs. freedom to make life choices
import plotly.express as px
fig = px.scatter(wh_df21, x="Social support", y="Freedom to make life choices", size="Logged GDP per capita", color="Regional indicator")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# There is a positive correlation between freedom to make life choices and social support in regions.
#
# The trend suggests that more social support for citizens is related to more freedom to make life choices.

# %%
#scatter plot standard deviation of perceptions of corruption vs. ladder score
import plotly.express as px
fig = px.scatter(wh_df21, x="Perceptions of corruption", y="Ladder score", size= "Logged GDP per capita", color="Regional indicator")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# There is a negative trend between the ladder score and perceptions of corruption among regions, with a couple of outliers.
#
# Generally, regions with a higher ladder score tend to have lower perceptions of corruption.

# %%
#pie chart for average ladder score per region
fig = px.pie(gb_wh21, values='Social support', names= 'Regional indicator', title='Average Social Support per Region')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The pie chart demonstrates that North American and AMZ and Western Europe have the highest levels of social support, whereas South Asia and Sub\-Saharan African have the lowest levels of social support compared to other regions.

# %%
#pie chart for average life expectancy per region
import plotly.express as px
fig = px.pie(gb_wh21, values='Healthy life expectancy', names= 'Regional indicator', title='Average Healthy Life Expectancy per Region')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#pie chart for countries per regional indicator
import plotly.express as px
count_wh_df21 = wh_df21.groupby('Regional indicator', as_index=False).count()
fig = px.pie(count_wh_df21, values='Country name', names= 'Regional indicator', title='Countries per Regional Indicator')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The pie chart demonstrates that Sub\-Saharan Africa has the most countries per region, and North America and ANZ have the least countries per region.

# %%
max_wh_df21 = wh_df21.groupby('Regional indicator', as_index=False).max()
max_wh_df21.head()
# Out:
#                    Regional indicator              Country name  Ladder score  \
# 0          Central and Eastern Europe                  Slovenia         6.965
# 1  Commonwealth of Independent States                Uzbekistan         6.179
# 2                           East Asia  Taiwan Province of China         6.584
# 3         Latin America and Caribbean                 Venezuela         7.069
# 4        Middle East and North Africa                     Yemen         7.157
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.059         7.062         6.868
# 1                           0.068         6.312         6.060
# 2                           0.049         6.659         6.510
# 3                           0.173         7.179         6.960
# 4                           0.076         7.224         7.090
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# ...

# %%
wh_df21['Ladder score'].nlargest(5) #Try more with this
# Out:
# 0    7.842
# 1    7.620
# 2    7.571
# 3    7.554
# 4    7.464
# Name: Ladder score, dtype: float64

# %%
def big_ladder(row):
    if row['Ladder score'] > 5:
        return True
    else:
        return False

wh_df21.apply(big_ladder, axis=1)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 144    False
# 145    False
# 146    False
# 147    False
# 148    False
# Length: 149, dtype: bool

# %%
gb_wh21 = wh_df21.groupby('Regional indicator', as_index=False).mean()
gb_wh21
# Out:
# /tmp/ipykernel_1134063/1763222910.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#                    Regional indicator  Ladder score  \
# 0          Central and Eastern Europe      5.984765
# 1  Commonwealth of Independent States      5.467000
# 2                           East Asia      5.810333
# 3         Latin America and Caribbean      5.908050
# 4        Middle East and North Africa      5.219765
# 5               North America and ANZ      7.128500
# 6                          South Asia      4.441857
# 7                      Southeast Asia      5.407556
# 8                  Sub-Saharan Africa      4.494472
# 9                      Western Europe      6.914905
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# ...

# %%
#pie chart for average freedom to make life choices per region
import plotly.express as px
fig = px.pie(gb_wh21, values='Freedom to make life choices', names= 'Regional indicator', title= 'Average Freedom to Make Life Choices per Region')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#pie chart for average gdp per capita per region
import plotly.express as px
fig = px.pie(gb_wh21, values='Logged GDP per capita', names= 'Regional indicator', title= 'Average GDP per Capita per Region')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
std_wh21 = wh_df21.groupby('Country name', as_index=False).std()
std_wh21.head()
# Out:
#   Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0  Afghanistan           NaN                             NaN           NaN
# 1      Albania           NaN                             NaN           NaN
# 2      Algeria           NaN                             NaN           NaN
# 3    Argentina           NaN                             NaN           NaN
# 4      Armenia           NaN                             NaN           NaN
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0           NaN                    NaN             NaN
# 1           NaN                    NaN             NaN
# 2           NaN                    NaN             NaN
# 3           NaN                    NaN             NaN
# 4           NaN                    NaN             NaN
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      NaN                           NaN         NaN
# ...

# %%
std_wh21 = wh_df21.groupby('Regional indicator', as_index=False).std()
std_wh21.head()
# Out:
#                    Regional indicator  Ladder score  \
# 0          Central and Eastern Europe      0.493325
# 1  Commonwealth of Independent States      0.438116
# 2                           East Asia      0.439913
# 3         Latin America and Caribbean      0.693467
# 4        Middle East and North Africa      0.999259
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.007169      0.488101      0.498848
# 1                        0.010323      0.442945      0.433885
# 2                        0.006542      0.440486      0.440218
# 3                        0.033798      0.658940      0.732526
# 4                        0.011219      0.992367      1.006575
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0               0.396190        0.068297                 1.909003
# 1               0.625180        0.080527                 1.167467
# 2               0.665074        0.053557                 5.194238
# ...

# %%
px.histogram(wh_df21, x = 'Ladder score', y = 'Regional indicator', color = 'Regional indicator')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(wh_df21, x = 'Regional indicator', y = 'Ladder score', color = 'Regional indicator')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter_geo(wh_df21, locations= 'Country name', color= 'Regional indicator', hover_name= 'Country name', size= 'Healthy life expectancy', animation_frame='Ladder score')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [261], in <cell line: 1>()
# ----> 1 px.scatter_geo(wh_df21, locations= 'Country name', color= 'Regional indicator', hover_name= 'Country name', size= 'Healthy life expectancy', animation_frame='Ladder score')
#
# File ~/miniconda3/lib/python3.10/site-packages/_plotly_utils/importers.py:39, in relative_import.<locals>.__getattr__(import_name)
#      36     class_module = importlib.import_module(rel_module, parent_name)
#      37     return getattr(class_module, class_name)
# ---> 39 raise AttributeError(
#      40     "module {__name__!r} has no attribute {name!r}".format(
#      41         name=import_name, __name__=parent_name
#      42     )
#      43 )
#
# AttributeError: module 'plotly' has no attribute 'scatter_geo'

# %%
import plotly as px
import plotly.graph_objects as go
go.Figure(data=[go.Scatter(x = 'Ladder score', y = 'Regional indicator', mode = 'markers', marker_size = 'Ladder score')])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [260], in <cell line: 3>()
#       1 import plotly as px
#       2 import plotly.graph_objects as go
# ----> 3 go.Figure(data=[go.Scatter(x = 'Ladder score', y = 'Regional indicator', mode = 'markers', marker_size = 'Ladder score')])
#
# ...

# %%
import plotly.express as px
fig = px.scatter_geo(wh_df21, locations = 'Country name', hover_name = 'Regional indicator', size = 'Ladder score', color = 'Regional indicator')

# %%
df = (wh_df21.groupby(["Country name", "Ladder score", "Regional indicator"])["Social support"].max()).reset_index()

# %%
df.head()
# Out:
#   Country name  Ladder score                  Regional indicator  \
# 0  Afghanistan         2.523                          South Asia
# 1      Albania         5.117          Central and Eastern Europe
# 2      Algeria         4.887        Middle East and North Africa
# 3    Argentina         5.929         Latin America and Caribbean
# 4      Armenia         5.283  Commonwealth of Independent States
#
#    Social support
# 0           0.463
# 1           0.697
# 2           0.802
# 3           0.898
# 4           0.799

# %%
from bubbly.bubbly import bubbleplot
figure = bubbleplot(dataset = wh_df21, x_column = "Ladder score", y_column = "Social support", bubble_column = "Country name", size_column = "Ladder score", color_column = "Regional indicator")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [265], in <cell line: 1>()
# ----> 1 from bubbly.bubbly import bubbleplot
#       2 figure = bubbleplot(dataset = wh_df21, x_column = "Ladder score", y_column = "Social support", bubble_column = "Country name", size_column = "Ladder score", color_column = "Regional indicator")
#
# ModuleNotFoundError: No module named 'bubbly'

# %%
fig = px.bar(data_canada, x='', y='') #what do we want to compare
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [266], in <cell line: 1>()
# ----> 1 fig = px.bar(data_canada, x='', y='')
#
# NameError: name 'data_canada' is not defined

# %%
wh_df21.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
min_wh21 = wh_df21.groupby('Ladder score', as_index=False).min()
min_wh21.head()
# Out:
#    Ladder score Country name  Regional indicator  \
# 0         2.523  Afghanistan          South Asia
# 1         3.145     Zimbabwe  Sub-Saharan Africa
# 2         3.415       Rwanda  Sub-Saharan Africa
# 3         3.467     Botswana  Sub-Saharan Africa
# 4         3.512      Lesotho  Sub-Saharan Africa
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.038         2.596         2.449
# 1                           0.058         3.259         3.030
# 2                           0.068         3.548         3.282
# 3                           0.074         3.611         3.322
# 4                           0.120         3.748         3.276
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                  7.695           0.463                   52.493
# 1                  7.943           0.750                   56.201
# 2                  7.676           0.552                   61.400
# ...

# %%
wh_df21.drop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [270], in <cell line: 1>()
# ----> 1 wh_df21.drop()
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
# ...

# %%
import plotly.express as px
fig = px.choropleth(wh_df21,locations = 'Country name',
                   locationmode='country names', color= 'Ladder score')
fig.update_layout(title = "World Happiness")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
fig = px.choropleth(wh_df21,locations = 'Country name',
                   locationmode='country names', color= 'Regional indicator')
fig.update_layout(title = "Regional Map")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
fig = px.scatter_geo(wh_df21, locations = "Country name", color = "Regional indicator")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.offline as po
import plotly.graph_objs as pg

layout = dict(title = 'Global GDP - robinson projection', 
              geo = dict( projection = {'type':'robinson'}, 
                         showlakes = True, 
                         lakecolor = 'rgb(0,191,255)'))
x = pg.Figure(data = [{type: "Scatter"}], wh_df21(['Healthy life expectancy']), layout = layout)
po.iplot(x)
# Out:
#   Input In [276]
#     x = pg.Figure(data = [{type: "Scatter"}], wh_df21(['Healthy life expectancy']), layout = layout)
#                                                                                                    ^
# SyntaxError: positional argument follows keyword argument

# %%
import pandas as pd
import plotly.offline as po
import plotly.graph_objs as pg

fig = pg.Figure(wh_df21, ['Ladder score'])
layout = dict(title = 'Global GDP - robinson projection', 
              geo = dict( projection = {'type':'robinson'}, 
                         showlakes = True, 
                         lakecolor = 'rgb(0,191,255)'))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [277], in <cell line: 5>()
#       2 import plotly.offline as po
#       3 import plotly.graph_objs as pg
# ----> 5 fig = pg.Figure(wh_df21, ['Ladder score'])
#       6 layout = dict(title = 'Global GDP - robinson projection',
#       7               geo = dict( projection = {'type':'robinson'},
#       8                          showlakes = True,
#       9                          lakecolor = 'rgb(0,191,255)'))
#      10 fig.show()
#
# File ~/miniconda3/lib/python3.10/site-packages/plotly/graph_objs/_figure.py:616, in Figure.__init__(self, data, layout, frames, skip_invalid, **kwargs)
#       5 def __init__(
#       6     self, data=None, layout=None, frames=None, skip_invalid=False, **kwargs
#       7 ):
#       8     """
#       9     Create a new :class:Figure instance
#      10
#    (...)
# ...

# %%
wh_df21
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
import plotly.express as px

# %%
import plotly.express as px
df = px.data.gapminder().query("year==2007")
fig = px.scatter_geo(df, locations="iso_alpha", color="continent", 
                    hover_name="gdpPercap", size="pop",
                    projection="natural earth")
map_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import folium
m = folium.Map
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [281], in <cell line: 1>()
# ----> 1 import folium
#       2 m = folium.Map
#
# ModuleNotFoundError: No module named 'folium'

# %%
wh_df21.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
import plotly.express as px

fig = px.imshow(wh_df21.corr(), text_auto=True)
fig.show()
# Out:
# /tmp/ipykernel_1134063/1546382088.py:3: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
wh_df21.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
import plotly.express as px
fig = px.bar(wh_df21, x='Ladder score', y='Regional indicator', title="Happiness Scale in Regions")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
fig = px.box(wh_df21, x="Ladder score", y="Regional indicator", title="Regional indicator vs Ladder Score")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
fig = px.box(wh_df21, x="Social support", y="Regional indicator", title="Regional indicator vs Social support")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
fig = px.box(wh_df21, x="Ladder score", y="Regional indicator", title="Ladder score vs Regional indicator")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
fig = px.scatter_geo(wh_df21,locations = 'Country name', size = 'Ladder score',
                   locationmode='country names', color= 'Regional indicator')
fig.update_layout(title = "World Happiness")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
fig = px.scatter_geo(wh_df21,locations = 'Country name', size = 'Healthy life expectancy',
                   locationmode='country names', color = ['Healthy life expectancy'])
fig.update_layout(title = "World Happiness")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [326], in <cell line: 2>()
#       1 import plotly.express as px
# ----> 2 fig = px.scatter_geo(wh_df21,locations = 'Country name', size = 'Healthy life expectancy',
#       3                    locationmode='country names', color = ['Healthy life expectancy'])
#       4 fig.update_layout(title = "World Happiness")
#       5 fig.show()
#
# ...

# %%
import GeoPandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [291], in <cell line: 1>()
# ----> 1 import GeoPandas as gpd
#
# ModuleNotFoundError: No module named 'GeoPandas'

# %%
wh_df21
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
import plotly.express as px
z = [[7.842, 7.620, 7.571, 7.554, 7.464],
    [7.392, ]]
fig = px.imshow(z, text_auto=True)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [293], in <cell line: 4>()
#       1 import plotly.express as px
#       2 z = [[7.842, 7.620, 7.571, 7.554, 7.464],
#       3     [7.392, ]]
# ----> 4 fig = px.imshow(z, text_auto=True)
#       5 fig.show()
#
# File ~/miniconda3/lib/python3.10/site-packages/plotly/express/_imshow.py:328, in imshow(img, zmin, zmax, origin, labels, x, y, animation_frame, facet_col, facet_col_wrap, facet_col_spacing, facet_row_spacing, color_continuous_scale, color_continuous_midpoint, range_color, title, template, width, height, aspect, contrast_rescaling, binary_string, binary_backend, binary_compression_level, binary_format, text_auto)
#     325     is_dataframe = False
#     327 # --------------- Starting from here img is always a numpy array --------
# --> 328 img = np.asanyarray(img)
# ...

# %%
print(wh_df21['Ladder score'].to_string(index=False))
# Out:
# 7.842
# 7.620
# 7.571
# 7.554
# 7.464
# 7.392
# 7.363
# 7.324
# 7.277
# 7.268
# 7.183
# 7.157
# 7.155
# 7.103
# 7.085
# 7.069
# 7.064
# 6.965
# 6.951
# 6.834
# 6.690
# 6.647
# 6.602
# 6.584
# 6.561
# 6.494
# 6.491
# 6.483
# 6.461
# 6.435
# 6.431
# 6.377
# 6.372
# 6.331
# 6.330
# 6.317
# 6.309
# 6.255
# 6.223
# 6.189
# 6.180
# 6.179
# 6.172
# 6.166
# 6.152
# 6.140
# 6.106
# 6.078
# 6.061
# 6.049
# 6.032
# 6.012
# 5.992
# 5.985
# 5.972
# 5.940
# 5.929
# 5.929
# 5.919
# 5.882
# 5.880
# 5.845
# 5.840
# 5.813
# 5.766
# 5.764
# 5.744
# 5.723
# 5.716
# 5.677
# 5.653
# 5.581
# 5.545
# 5.536
# 5.534
# 5.477
# 5.477
# 5.466
# 5.411
# 5.410
# 5.384
# 5.345
# 5.342
# 5.339
# 5.306
# 5.283
# 5.269
# 5.266
# 5.198
# 5.171
# 5.142
# 5.132
# 5.117
# 5.101
# 5.088
# 5.074
# 5.066
# 5.051
# 5.045
# 5.030
# 5.025
# 4.984
# 4.956
# 4.948
# 4.934
# 4.918
# 4.892
# 4.891
# 4.887
# 4.875
# 4.854
# 4.852
# 4.834
# 4.830
# 4.794
# 4.759
# 4.723
# 4.721
# 4.636
# 4.625
# 4.607
# 4.596
# 4.584
# 4.574
# 4.517
# ...

# %%
import plotly.express as px
data=[[7.842, 7.620, 7.571, 7.554, 7.464],
   [7.392, 7.363, 7.324, 7.277, 7.268], 
   [7.183, 7.157, 7.155, 7.103, 7.085], 
   [7.069, 7.064, 6.965, 6.951, 6.834],
   [6.690, 6.647, 6.602, 6.584, 6.561], 
   [6.494, 6.491, 6.483, 6.461, 6.435], 
   [6.431, 6.377, 6.372, 6.331, 6.330], 
   [6.317, 6.309, 6.255, 6.223, 6.189], 
   [6.180, 6.179, 6.172, 6.166, 6.152]]
fig = px.imshow(z, text_auto=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
z = [[7.842, 7.620, 7.571, 7.554, 7.464],
    [7.392, 7.363, 7.324, 7.277, 7.268],
    [7.183, 7.157, 7.155, 7.103, 7.085],
    [7.069, 7.064, 6.965, 6.951, 6.834],
    [6.690, 6.647, 6.602, 6.584, 6.561],
    [6.494, 6.491, 6.483, 6.461, 6.435],
    [6.431, 6.377, 6.372, 6.331, 6.330],
    [6.317, 6.309, 6.255, 6.223, 6.189],
    [6.180, 6.179, 6.172, 6.166, 6.152],
    [6.140, 6.106, 6.078, 6.061, 6.049],
    [6.032, 6.012, 5.992, 5.985, 5.972],
    [5.940, 5.929, 5.929, 5.919, 5.882],
    [5.880, 5.845, 5.840, 5.813, 5.766],
    [5.764, 5.744, 5.723, 5.716, 5.677],
    [5.653, 5.581, 5.545, 5.536, 5.534],
    [5.477, 5.477, 5.466, 5.411, 5.410],
    [5.384, 5.345, 5.342, 5.339, 5.306],
    [5.283, 5.269, 5.266, 5.198, 5.171],
    [5.142, 5.132, 5.117, 5.101, 5.088],
    [5.074, 5.066, 5.051, 5.045, 5.030],
    [5.025, 4.984, 4.956, 4.948, 4.934],
    [4.918, 4.892, 4.891, 4.887, 4.875],
    [4.854, 4.852, 4.834, 4.830, 4.794],
    [4.759, 4.723, 4.721, 4.636, 4.625],
    [4.607, 4.596, 4.584, 4.574, 4.517],
    [4.426, 4.395, 4.355, 4.325, 4.308],
    [4.289, 4.283, 4.275, 4.227, 4.208],
    [4.107, 4.073, 3.849, 3.819, 3.775],
    [3.658, 3.623, 3.615, 3.600, 3.512],
    [3.467, 3.415, 3.145, 2.523]]

# %%
fig = px.imshow(z, text_auto=True)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [307], in <cell line: 1>()
# ----> 1 fig = px.imshow(z, text_auto=True)
#       2 fig.show()
#
# File ~/miniconda3/lib/python3.10/site-packages/plotly/express/_imshow.py:328, in imshow(img, zmin, zmax, origin, labels, x, y, animation_frame, facet_col, facet_col_wrap, facet_col_spacing, facet_row_spacing, color_continuous_scale, color_continuous_midpoint, range_color, title, template, width, height, aspect, contrast_rescaling, binary_string, binary_backend, binary_compression_level, binary_format, text_auto)
#     325     is_dataframe = False
#     327 # --------------- Starting from here img is always a numpy array --------
# --> 328 img = np.asanyarray(img)
#     329 # Reshape array so that animation dimension comes first, then facets, then images
#     330 if facet_col is not None:
#
# ...

# %%
import plotly.express as px
fig = px.violin(wh_df21, y="Regional indicator")
fig.show()

# %%
import pandas as pd
wh_df21 = pd.read_csv('data/world-happiness-report-2021.csv')
print(wh_df21['Ladder score'].to_string(index=False))

# %%
fig = px.scatter_geo(wh_df21,locations = 'Country name', size = 'Ladder score',
                   locationmode='country names', color= 'Healthy life expectancy')
fig.update_layout(title = "World Happiness")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter_geo(wh_df21,locations = 'Country name', size = 'Ladder score',
                   locationmode='country names', color= 'Logged GDP per capita')
fig.update_layout(title = "World Happiness")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
