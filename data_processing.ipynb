# %%
import plotly.graph_objects as go
import pandas as pd

import pandas as pd
import plotly.express as px

# %%
pd.set_option('display.max_colwidth', None)
definitions = pd.read_csv('data/Features definition.csv')
definitions
# Out:
#                       Features   \
# 0                  Country name
# 1  Freedom to make life choices
# 2                    Generosity
# 3       Healthy life expectancy
# 4                  Ladder score
# 5     Ladder Score in Dystopia
# 6         Logged GDP per capita
# 7     Perceptions of Corruption
# 8            Regional indicator
# 9                Social support
#
#                                                                                                                                                                                                        Definition
# 0                                                                                                                                                                                             Name of the country
# ...

# %%
avg_wh21
# Out:
#                    Regional indicator  Ladder score  Logged GDP per capita  \
# 0          Central and Eastern Europe      5.984765              10.109059
# 1  Commonwealth of Independent States      5.467000               9.401833
# 2                           East Asia      5.810333              10.367667
# 3         Latin America and Caribbean      5.908050               9.370000
# 4        Middle East and North Africa      5.219765               9.666118
# 5               North America and ANZ      7.128500              10.809500
# 6                          South Asia      4.441857               8.682571
# 7                      Southeast Asia      5.407556               9.421444
# 8                  Sub-Saharan Africa      4.494472               8.075194
# 9                      Western Europe      6.914905              10.822714
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
import pandas as pd
import plotly.express as px

wh_df = pd.read_csv('data/world-happiness-report.csv')
wh_df21 = pd.read_csv('data/world-happiness-report-2021.csv')

# %%
wh_df.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
wh_df[wh_df['Country name'] == 'Afghanistan']
# Out:
#    Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0   Afghanistan  2008        3.724               7.370           0.451
# 1   Afghanistan  2009        4.402               7.540           0.552
# 2   Afghanistan  2010        4.758               7.647           0.539
# 3   Afghanistan  2011        3.832               7.620           0.521
# 4   Afghanistan  2012        3.783               7.705           0.521
# 5   Afghanistan  2013        3.572               7.725           0.484
# 6   Afghanistan  2014        3.131               7.718           0.526
# 7   Afghanistan  2015        3.983               7.702           0.529
# 8   Afghanistan  2016        4.220               7.697           0.559
# 9   Afghanistan  2017        2.662               7.697           0.491
# 10  Afghanistan  2018        2.694               7.692           0.508
# 11  Afghanistan  2019        2.375               7.697           0.420
#
# ...

# %%
wh_df21
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
wh_df21.describe() #A little more description of the data
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %%
wh_df21.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
#Questions formulated to recieve data
#Social Support=  “If you were in trouble, do you have relatives or friends you can count on to help you whenever you need them, or not?” (0=no, 1=yes)
#Freedom= "Are you satisfied or dissatisfied with your freedom to choose what you do with your life?”(0=no 1=yes)
#Generosity= “Have you donated money to a charity in the past month?”
#Corruption= "Is corruption widespread throughout the government in this country or not?” this is also applied with gov information

# %%
# meaning of column names

# Country name - Essential
# Regional Indicator is the region of the country and could be used when looking at data on a wider scale
# Ladder Score: rate their own current lives on a scalre of 0 to 10 (0 = worst, 10 = best)
# Standerd Error of Ladder Score: the statistical accuracy of the measurement - not essential
# Upper/Lower Whisker: the values between Q3 and max (Upper) and the values between min and Q1 (lower) - not essential
# Logged GDP capita - Essential
# Social Support: Assitance provided by the community to an individual - Red Flag (what's it measured in).
# Healthy Life Expectancy: Average number of years that a person can expect to live in full health - Essential
# Freedom to make Life Choices - Red Flag (very vague)
# Generosity: the average response to the question "Have you donated money to charity in the past month" - not essential or relevant
# Perceptions of Corruption: The measure is the national average of the survey responses to two questions in the GWP: “Is corruption widespread throughout the government or not” and “Is corruption widespread within businesses or not?” - Red Flag (could recieve biased responses)
# Ladder Score in Dystopia - The precentage of happiness in a country compare to the "world saddest country"(a dystopia where all the column values are low) not essential
# Explained By Columns - not essential

# %%
# dropping columns

columns_to_drop = ['Standard error of ladder score', 'upperwhisker', 'lowerwhisker', 'Explained by: Log GDP per capita', 'Explained by: Social support',
       'Explained by: Healthy life expectancy',
       'Explained by: Freedom to make life choices',
       'Explained by: Generosity', 'Explained by: Perceptions of corruption']
wh_df21.drop(columns_to_drop, axis=1, inplace = True)

# %%
Social_support= wh_df21['Social support']

# %%
Social_support.max()
# Out:
# 0.983

# %%
Social_support.min()
# Out:
# 0.463

# %%
wh_df21.shape #number of rows and columns in dataset
# Out:
# (149, 11)

# %%
wh_df21.dropna(inplace=True)
wh_df21.reset_index(drop=True, inplace=True) #to drop na values

# %%
wh_df21['Regional indicator'].value_counts() #number of countries within regions
# Out:
# Sub-Saharan Africa                    36
# Western Europe                        21
# Latin America and Caribbean           20
# Middle East and North Africa          17
# Central and Eastern Europe            17
# Commonwealth of Independent States    12
# Southeast Asia                         9
# South Asia                             7
# East Asia                              6
# North America and ANZ                  4
# Name: Regional indicator, dtype: int64

# %%
wh_df21
# Out:
#     Country name  Regional indicator  Ladder score  Logged GDP per capita  \
# 0        Finland      Western Europe         7.842                 10.775
# 1        Denmark      Western Europe         7.620                 10.933
# 2    Switzerland      Western Europe         7.571                 11.117
# 3        Iceland      Western Europe         7.554                 10.878
# 4    Netherlands      Western Europe         7.464                 10.932
# ..           ...                 ...           ...                    ...
# 144      Lesotho  Sub-Saharan Africa         3.512                  7.926
# 145     Botswana  Sub-Saharan Africa         3.467                  9.782
# 146       Rwanda  Sub-Saharan Africa         3.415                  7.676
# 147     Zimbabwe  Sub-Saharan Africa         3.145                  7.943
# 148  Afghanistan          South Asia         2.523                  7.695
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
wh_df.columns #to compare with 2021 columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
import plotly.express as px #importing plotly for any future usage

# %%
#scatter plot: Freedom to make life choices vs. Perceptions of corruption
fig = px.scatter(wh_df21, x="Freedom to make life choices", y="Perceptions of corruption", color="Country name", title="Freedom vs Corruption by Location & Dystopia",
                size="Dystopia + residual", trendline="ols")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# scatter plot: Healthy Life Expectancy vs. Ladder Score

fig_hle_vs_ls = px.scatter(wh_df21, x = 'Healthy life expectancy', y = 'Ladder score', color = 'Country name', title = 'Healthy Life Expectancy vs. Ladder Score', trendline="ols")
fig_hle_vs_ls.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# conclusion: shows positive, medium/strong correlation
#
# in general, the higher the healthy life expectancy, the higher the ladder score & the happier the general country is.
#
# a couple of outliers \(high healthy life expectancy but relatively lower ladder score\)

# %%
#scatter plot gdp vs. generosity
import plotly.express as px
fig = px.scatter(wh_df21, x="Logged GDP per capita", y="Generosity", size="Healthy life expectancy", color="Country name")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# !pip install statsmodel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement statsmodel (from versions: none)
# ERROR: No matching distribution found for statsmodel

# %%
wh_df21.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
import statsmodels.api as sm
model = sm.OLS(wh_df21['Healthy life expectancy'], wh_df21['Logged GDP per capita']).fit()
fitted_vals=model.fittedvalues

fig = px.scatter(wh_df21, x="Logged GDP per capita", y="Healthy life expectancy", color="Regional indicator",
                 title="GDP by Healthy Life Expectancy")

# regression data
fig.add_trace(go.Scatter(x=wh_df21['Logged GDP per capita'],
                         y=fitted_vals,
                         mode='lines',
                         name='best fit',
                         line=dict(color='firebrick', width=2)
                        ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(wh_df21, x="Logged GDP per capita", y="Healthy life expectancy", color="Regional indicator",
                 title="GDP by Healthy Life Expectancy")

fig.add_trace(   #figure out how to do ols in just x and in just y
    go.Scatter(
        x=avg_wh21["Logged GDP per capita"],
        y=avg_wh21["Healthy life expectancy"],
        mode="lines",
        line=go.scatter.Line(color="gray"),
        showlegend=False)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#scatter plot gdp vs. life expectancy
import plotly.express as px
fig = px.scatter(wh_df21, x="Logged GDP per capita", y="Healthy life expectancy", trendline="ols", color='Regional indicator')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#scatter matrix
numerical_wh_df21 = wh_df21[['Logged GDP per capita', 'Healthy life expectancy', 'Ladder score']]
fig = px.scatter_matrix(numerical_wh_df21, color='Healthy life expectancy')
fig.show()
# Out:
# /projects/edd1874b-535e-4ea0-8897-aa8a85e79c89/miniconda3/lib/python3.10/site-packages/plotly/express/_core.py:279: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#pie chart for ladder score per region
fig = px.pie(wh_df21, values='Ladder score', names= 'Regional indicator', title='Ladder Score per Region')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#pie chart for life expectancy per region
fig = px.pie(gb_wh21, values='Healthy life expectancy', names= 'Regional indicator', title='Healthy Life Expectancy per Region')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [277], in <cell line: 2>()
#       1 #pie chart for life expectancy per region
# ----> 2 fig = px.pie(gb_wh21, values='Healthy life expectancy', names= 'Regional indicator', title='Healthy Life Expectancy per Region')
#       3 fig.show()
#
# NameError: name 'gb_wh21' is not defined

# %%
# px.histogram(wf_

# %%
print(wh_df21['Regional indicator'].unique())
avg_wh21 = wh_df21.groupby('Regional indicator', as_index=False).mean()
std_wh21 = wh_df21.groupby('Regional indicator', as_index=False).std()
# Out:
# ['Western Europe' 'North America and ANZ' 'Middle East and North Africa'
#  'Latin America and Caribbean' 'Central and Eastern Europe' 'East Asia'
#  'Southeast Asia' 'Commonwealth of Independent States'
#  'Sub-Saharan Africa' 'South Asia']
# /tmp/ipykernel_1135080/495623554.py:2: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
# ave of ladder score in each region with standard deviation & errors

import plotly.graph_objects as go
#px.bar(avg_wh21, x = 'Regional indicator', y = 'Ladder score', color = 'Regional indicator', labels = {'Ladder score':'Ave of Ladder Score'}, title = 'Ave of Ladder Score in Different Regions')
fig = go.Figure()
fig.add_trace(go.Bar(
    name='Control',
    x=avg_wh21['Regional indicator'], y=avg_wh21['Ladder score'],
    error_y=dict(type='data', array=std_wh21['Ladder score'])
))
fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# healthy life expectancy by region

fig = px.bar(avg_wh21, x='Regional indicator', y='Healthy life expectancy', color = 'Regional indicator', title='Healthy Life Expectancy by Region')
error_y=dict(type='Healthy life expectancy') 
# fig.xaxis.automargin = True
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# healthy life expectancy by region with standard deviation & errors

# fig = px.bar(avg_wh21, x='Regional indicator', y='Healthy life expectancy', color = 'Regional indicator', title='Healthy Life Expectancy by Region')
fig = go.Figure()
fig.add_trace(go.Bar(
    name='Control',
    x=avg_wh21['Regional indicator'], y=avg_wh21['Healthy life expectancy'],
    error_y=dict(type='data', array=std_wh21['Healthy life expectancy'])
))
fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# fig = px.bar(avg_wh21, x='Regional indicator', y='Logged GDP per capita', color = 'Regional indicator', title='Logged GDP per Capita by Region')
# fig.show()

# logged GDP per capita by region with standard deviation & errors

fig = go.Figure()
fig.add_trace(go.Bar(
    name='Control',
    x=avg_wh21['Regional indicator'], y=avg_wh21['Logged GDP per capita'],
    error_y=dict(type='data', array=std_wh21['Logged GDP per capita'])
))
fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# ave of social support in each region with standard deviation & errors

#px.bar(avg_wh21, x = 'Regional indicator', y = 'Social support', color = 'Regional indicator', title = 'Ave of Social Support in Different Regions')
fig = go.Figure()
fig.add_trace(go.Bar(
    name='Control',
    x=avg_wh21['Regional indicator'], y=avg_wh21['Social support'],
    error_y=dict(type='data', array=std_wh21['Social support'])
))
fig.update_layout(barmode='group', xaxis={'nticks': 10, 'tickangle': 45})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
avg_wh21['Generosity']
# Out:
# 0   -0.078941
# 1   -0.036000
# 2   -0.062333
# 3   -0.067700
# 4   -0.079765
# 5    0.120000
# 6    0.042714
# 7    0.156333
# 8    0.013444
# 9   -0.003190
# Name: Generosity, dtype: float64

# %%
# generosity by region with standard deviation & errors

px.bar(avg_wh21, x='Regional indicator', y='Generosity', color = 'Regional indicator', title='Generosity by Region')

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Bar(
    name='Control',
    x=avg_wh21['Regional indicator'], y=avg_wh21['Generosity'],
    error_y=dict(type='data', array=std_wh21['Generosity'])
))
fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
std_wh21 = wh_df21.groupby('Regional indicator', as_index=False).std()
# px.box(avg_wh21, x='Regional indicator', y="Ladder score in Dystopia", color = 'Regional indicator', title='Dystopian Ladder Score by Region')
px.bar(avg_wh21, x='Regional indicator', y='Ladder score in Dystopia', color = 'Regional indicator', title='Dystopian Ladder Score by Region')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# ave of freedom to make life choices in each region with standard deviation & errors

#px.bar(avg_wh21, x = 'Regional indicator', y = 'Freedom to make life choices', color = 'Regional indicator', title = 'Ave of Freedom to Make Life Choices in Different Regions')
fig = go.Figure()
fig.add_trace(go.Bar(
    name='Control',
    x=avg_wh21['Regional indicator'], y=avg_wh21['Freedom to make life choices'],
    error_y=dict(type='data', array=std_wh21['Freedom to make life choices']),
marker_color = px.colors.qualitative.Plotly
))
fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# ave of perceptions of corruption in each region with standard deviation & errors

#px.bar(avg_wh21, x = 'Regional indicator', y = 'Perceptions of corruption', color = 'Regional indicator', title = 'Ave of Perceptions of corruption in Different Regions')
fig = go.Figure()
fig.add_trace(go.Bar(
    name='Control',
    x=avg_wh21['Regional indicator'], y=avg_wh21['Perceptions of corruption'],
    error_y=dict(type='data', array=std_wh21['Perceptions of corruption']),
marker_color = px.colors.qualitative.Plotly
))
fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.colors.qualitative.Plotly
# Out:
# ['#636EFA',
#  '#EF553B',
#  '#00CC96',
#  '#AB63FA',
#  '#FFA15A',
#  '#19D3F3',
#  '#FF6692',
#  '#B6E880',
#  '#FF97FF',
#  '#FECB52']

# %%
# ave of dystopia + residual in each region with standard deviation & errors

#px.bar(avg_wh21, x = 'Regional indicator', y = 'Dystopia + residual', color = 'Regional indicator', title = 'Ave of Dystopia + Residual in Different Regions')
fig = go.Figure()
fig.add_trace(go.Bar(
    name='Control',
    x=avg_wh21['Regional indicator'], y=avg_wh21['Dystopia + residual'],
    error_y=dict(type='data', array=std_wh21['Dystopia + residual']),
    marker_color = px.colors.qualitative.Plotly
))
fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import numpy as np
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=avg_wh21['Regional indicator'],
    y=wh_df21['Ladder score']
))
fig.add_trace(go.Line(
        x=avg_wh21['Regional indicator'],
        y=avg_wh21['Ladder score']
))

fig.show()
# Out:
# /projects/edd1874b-535e-4ea0-8897-aa8a85e79c89/miniconda3/lib/python3.10/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#px.scatter(std_wh21, x="Logged GDP per capita", y="Social support", trendline='ols')
#how do we do a line of best fit graph?

# %%
avg_wh21
# Out:
#                    Regional indicator  Ladder score  Logged GDP per capita  \
# 0          Central and Eastern Europe      5.984765              10.109059
# 1  Commonwealth of Independent States      5.467000               9.401833
# 2                           East Asia      5.810333              10.367667
# 3         Latin America and Caribbean      5.908050               9.370000
# 4        Middle East and North Africa      5.219765               9.666118
# 5               North America and ANZ      7.128500              10.809500
# 6                          South Asia      4.441857               8.682571
# 7                      Southeast Asia      5.407556               9.421444
# 8                  Sub-Saharan Africa      4.494472               8.075194
# 9                      Western Europe      6.914905              10.822714
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
import plotly.express as px
import pandas as pd
wh_df21 = pd.read_csv('data/world-happiness-report-2021.csv')
fig = px.violin(wh_df21, x='Regional indicator', y="Social support", title="Regional indicator vs. Social support")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd
wh_df21 = pd.read_csv('data/world-happiness-report-2021.csv')
fig = px.violin(wh_df21, x='Regional indicator', y="Freedom to make life choices", title="Regional indicator vs. Freedom")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.violin(wh_df21, x='Regional indicator', y="Logged GDP per capita", title="Regional indicator vs. GDP per capita")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd
wh_df21 = pd.read_csv('data/world-happiness-report-2021.csv')
fig = px.violin(wh_df21, x="Regional indicator", y="Generosity", title="Regional indicator vs. Generosity")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.violin(wh_df21, x='Regional indicator', y="Perceptions of corruption", title="Regional indicator vs. Perceptions of corruption")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
abc = 5

# %%
abc
# Out:
# 5

# %%
abc
# Out:
# 5
